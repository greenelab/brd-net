# %% [markdown]
# # Compare Models
# ---
# Compare the performance of various outlier detection and classifier models in differentiating between healthy and unhealthy gene expression.

# %%
import pandas
from plotnine import *

# %% [markdown]
# ### Compare the accuracy of each model on ten different validation sets

# %%
# Load the dataframe generated by evaluate_models.py
result_df = pandas.read_csv('../results/model_eval_results.csv', index_col=0)

result_df['acc_over_baseline'] = result_df['val_acc'] - result_df['val_baseline']

result_df.head()
# Out:
#                 Model     LR  Seed   val_acc  val_auroc  val_baseline  \
# 0             IForest  0.001     0  0.601959   0.505913      0.589492
# 1               OCSVM  0.001     0  0.410508   0.532477      0.589492
# 2  LogisticRegression  0.001     0  0.764025   0.768746      0.589492
# 3                 MLP  0.001     0  0.682101   0.673849      0.589492
# 4         TenLayerNet  0.001     0  0.758682   0.829938      0.589492
#
#    acc_over_baseline
# 0           0.012467
# 1          -0.178985
# 2           0.174532
# 3           0.092609
# 4           0.169190

# %%
ggplot(result_df, aes(x='Model', y='val_acc', color='factor(LR)')) + geom_point()
# Out:
# /home/ben/anaconda3/envs/brdnet/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/ben/anaconda3/envs/brdnet/lib/python3.7/site-packages/plotnine/layer.py:449: UserWarning: geom_point : Removed 40 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# /home/ben/anaconda3/envs/brdnet/lib/python3.7/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (-9223363285545796180)>

# %% [markdown]
# ### Plot adjusted accuracy
# ---
# Since the accuracy measurements are based on different validation sets, it makes sense to compare them to a baseline model. In this case, the baseline predicts that every sample is from the larger class. The field `acc_over_baseline` is generated by subtracting the baseline model's accuracy from the main model.

# %%
ggplot(result_df, aes(x='Model', y='acc_over_baseline', color='factor(LR)')) + geom_point()
# Out:
# /home/ben/anaconda3/envs/brdnet/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/ben/anaconda3/envs/brdnet/lib/python3.7/site-packages/plotnine/layer.py:449: UserWarning: geom_point : Removed 40 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# /home/ben/anaconda3/envs/brdnet/lib/python3.7/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (8751309016289)>

# %% [markdown]
# ### Plot AUROC
# ---
# The area under the receiver operating curve is a metric that compares the tradeoff between the models' true positive rate and false positive rate.

# %%
ggplot(result_df, aes(x='Model', y='val_auroc', color='factor(LR)')) + geom_point()
# Out:
# /home/ben/anaconda3/envs/brdnet/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /home/ben/anaconda3/envs/brdnet/lib/python3.7/site-packages/plotnine/layer.py:449: UserWarning: geom_point : Removed 40 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# /home/ben/anaconda3/envs/brdnet/lib/python3.7/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (8751308833740)>
